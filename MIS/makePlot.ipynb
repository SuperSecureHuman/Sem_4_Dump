# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("benchmark_results.csv")

# %%
df
# Out:
#     n_samples  admm_iter_time  admm_iter_errors  admm_parallel_time  \
# 0       10000        0.363595          0.923369            3.031580
# 1       11000        0.377264          0.918113            2.157202
# 2       12000        0.419432          1.041844            2.061826
# 3       13000        0.430331          0.943762            2.346725
# 4       14000        0.478889          1.045355            2.351719
# ..        ...             ...               ...                 ...
# 85      95000        2.998268          0.989680           10.904728
# 86      96000        3.028628          0.991277           10.857395
# 87      97000        3.072438          0.989367           10.888359
# 88      98000        3.001469          0.992432           10.956971
# 89      99000        3.103980          0.988222           11.411610
#
#     admm_parallel_errors  admm_cpu_time  admm_cpu_errors  admm_gpu_time  \
# 0            8513.528461       0.166425         0.917268       0.301738
# ...

# %%
plt.figure(figsize=(25, 15))

# Plot admm_iter_time with smoothing
sns.lineplot(x=df["n_samples"], y=df["admm_iter_time"], label="Parallel", linewidth=2.5, ci=None)

# Plot admm_parallel_time with smoothing
sns.lineplot(x=df["n_samples"], y=df["admm_parallel_time"], label="Iterative", linewidth=2.5, ci=None)

# Plot admm_cpu_time with smoothing
sns.lineplot(x=df["n_samples"], y=df["admm_cpu_time"], label="Torch CPU", linewidth=2.5, ci=None)

# Plot admm_gpu_time with smoothing
sns.lineplot(x=df["n_samples"], y=df["admm_gpu_time"], label="Torch GPU", linewidth=2.5, ci=None)

plt.xlabel("n_samples")
plt.ylabel("Time (seconds)")
plt.title("ADMM Time Comparison")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_58397/833368090.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x=df["n_samples"], y=df["admm_iter_time"], label="Parallel", linewidth=2.5, ci=None)
# /tmp/ipykernel_58397/833368090.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x=df["n_samples"], y=df["admm_parallel_time"], label="Iterative", linewidth=2.5, ci=None)
# /tmp/ipykernel_58397/833368090.py:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x=df["n_samples"], y=df["admm_cpu_time"], label="Torch CPU", linewidth=2.5, ci=None)
# /tmp/ipykernel_58397/833368090.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x=df["n_samples"], y=df["admm_gpu_time"], label="Torch GPU", linewidth=2.5, ci=None)
